# %% [markdown]
# <a href="https://colab.research.google.com/github/Arnav-Barman/UML501-ML/blob/main/Assignment_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Assignment 1: UML501
# ---

# %%
import numpy as np

# %% [markdown]
# Q1
#
#  ![image.png](data:image/png;base64,...)

# %%
arr = np.array([1,2,3,6,4,5])

# %%
revarr = np.flip(arr)
revarr
# Out:
# array([5, 4, 6, 3, 2, 1])

# %%
rarr = arr[::-1]
rarr
# Out:
# array([5, 4, 6, 3, 2, 1])

# %% [markdown]
# Q1
#
# ![image.png](data:image/png;base64,...)

# %%
array1 = np.array([[1,2,3],[2,4,5],[1,2,3]])

# %%
array1.flatten()
#flatten row wise
# Out:
# array([1, 2, 3, 2, 4, 5, 1, 2, 3])

# %%
array1.flatten('F')
#flatten column wise
# Out:
# array([1, 2, 1, 2, 4, 2, 3, 5, 3])

# %% [markdown]
# Q1
#
# ![image.png](data:image/png;base64,...)

# %%
arr1 = np.array([[1,2],[3,4]])
arr2 = np.array([[1,2],[3,4]])

print("Array 1:",arr1)
print("Array 2:",arr2)

print("Array 1 > Array 2", np.greater(arr1,arr2))
print("Array 1 >= Array 2", np.greater_equal(arr1,arr2))
print("Array 1 < Array 2", np.less(arr1,arr2))
print("Array 1 <= Array 2", np.less_equal(arr1,arr2))
print("Array 1 == Array 2", np.equal(arr1,arr2))
print("Array 1 != Array 2", np.not_equal(arr1,arr2))
# Out:
# Array 1: [[1 2]
#  [3 4]]
# Array 2: [[1 2]
#  [3 4]]
# Array 1 > Array 2 [[False False]
#  [False False]]
# Array 1 >= Array 2 [[ True  True]
#  [ True  True]]
# Array 1 < Array 2 [[False False]
#  [False False]]
# Array 1 <= Array 2 [[ True  True]
#  [ True  True]]
# Array 1 == Array 2 [[ True  True]
#  [ True  True]]
# Array 1 != Array 2 [[False False]
#  [False False]]

# %% [markdown]
# Q1
#
#  ![image.png](data:image/png;base64,...)

# %%
x = np.array([1,2,3,4,5,1,2,1,1,1])
y = np.array([1,1,1,2,3,4,2,4,3,3])

print("X array:",x)
print("Y array:",y)

x1 = np.bincount(x)
max_x1 = max(x1)
print("x1 array:",x1)

y1 = np.bincount(y)
max_y1 = max(y1)
print("y1 array:",y1)

print("Max freq. element of array x are:")
for i in range(len(x1)):
  if x1[i]==max_x1:
    print(i, end=" ")

print("\nMax freq. element of array y are:")
for i in range(len(y1)):
  if y1[i]==max_y1:
    print(i, end=" ")
# Out:
# X array: [1 2 3 4 5 1 2 1 1 1]
# Y array: [1 1 1 2 3 4 2 4 3 3]
# x1 array: [0 5 2 1 1 1]
# y1 array: [0 3 2 3 2]
# Max freq. element of array x are:
# 1
# Max freq. element of array y are:
# 1 3

# %% [markdown]
# Q1
#
# ![image.png](data:image/png;base64,...)

# %%
gfg = np.matrix('[4,1,9;12,3,1;4,5,6]')
print("The matrix:", gfg)
print("\nSum of all elements:", gfg.sum())
print("\nSum of all elements of a row:", gfg.sum(axis=1))
print("\nSum of all elements of a column:", gfg.sum(axis=0))
# Out:
# The matrix: [[ 4  1  9]
#  [12  3  1]
#  [ 4  5  6]]
#
# Sum of all elements: 45
#
# Sum of all elements of a row: [[14]
#  [16]
#  [15]]
#
# Sum of all elements of a column: [[20  9 16]]

# %% [markdown]
# Q1
#
# ![image.png](data:image/png;base64,...)

# %%
n_array = np.array([[55,25,15],[30,44,2],[11,45,77]])
print("The array is:",n_array)

dsum=0
for i in range(len(n_array)):
  for j in range(len(n_array[0])):
    if i == j:
      dsum = dsum + n_array[i][j]

print("\nThe sum of diagonal elements is: ",dsum)

eval, evect = np.linalg.eig(n_array)
print("\nThe eigen values of the matrix are:", eval)
print("\nThe eigen vectors of the matrix are:", evect)

invArr = np.linalg.inv(n_array)
print("\nThe inverse of the array is:",invArr)

detArr = np.linalg.det(n_array)
print("\nThe determinant of the array is:",detArr)
# Out:
# The array is: [[55 25 15]
#  [30 44  2]
#  [11 45 77]]
#
# The sum of diagonal elements is:  176
#
# The eigen values of the matrix are: [98.16835147 28.097044   49.73460452]
#
# The eigen vectors of the matrix are: [[ 0.4574917   0.34637121 -0.15017693]
#  [ 0.28447814 -0.72784061 -0.4852124 ]
#  [ 0.84248058  0.59184038  0.8614034 ]]
#
# The inverse of the array is: [[ 0.02404141 -0.00911212 -0.00444671]
#  [-0.01667882  0.02966905  0.0024785 ]
#  [ 0.00631287 -0.01603732  0.01217379]]
#
# The determinant of the array is: 137180.0000000001

# %% [markdown]
# Q1
#
# ![image.png](data:image/png;base64,...)

# %%
p1 = np.array([[1,2],[3,4]])
print("Array p1:\n",p1)
q1 = np.array([[4,5],[6,7]])
print("Array q1:\n",q1)
print("Product of pq and q1:\n",np.matmul(p1,q1))

output = []
for a,b in zip(p1,q1):
    cov = np.cov(a, b)
    output.append(cov[0][1])
print("Covariance between p1 and q1:\n",output)


p2 = np.array([[1,2],[2,3],[4,5]])
print("Array p2:\n",p2)
q2 = np.array([[4,5,1],[6,7,2]])
print("Array q2:\n",q2)
print("Product of p2 and q2:\n",np.matmul(p2,q2))

output2 = []
for a,b in zip(p2,q2):
    cov = np.cov(a, b)
    output2.append(cov[0][1])
print("Covariance between p1 and q1:\n",output2)

# %% [markdown]
# Q1
#
# ![image.png](data:image/png;base64,...)

# %%
x2=np.array([[2,3,4],[3,2,9]])
print("Array x2:\n",x2)
y2=np.array([[1,5,0],[5,10,3]])
print("Array y2:\n",y2)
print("Inner Product:\n",np.inner(x2,y2))
print("Outer Product:\n",np.outer(x2,y2))
print("Cross Product:\n",np.cross(x2,y2))
# Out:
# Array x2:
#  [[2 3 4]
#  [3 2 9]]
# Array y2:
#  [[ 1  5  0]
#  [ 5 10  3]]
# Inner Product:
#  [[17 52]
#  [13 62]]
# Outer Product:
#  [[ 2 10  0 10 20  6]
#  [ 3 15  0 15 30  9]
#  [ 4 20  0 20 40 12]
#  [ 3 15  0 15 30  9]
#  [ 2 10  0 10 20  6]
#  [ 9 45  0 45 90 27]]
# Cross Product:
#  [[-20   4   7]
#  [-84  36  20]]

# %% [markdown]
# ---

# %% [markdown]
# Q2
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Q2
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ---

# %% [markdown]
# Q3
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Q3
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ---

# %% [markdown]
# Q4
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Q4
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ---
